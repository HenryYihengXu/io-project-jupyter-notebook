# %%
import sys
import os
import numpy as np
import pandas as pd
sys.path.insert(1, os.path.join(sys.path[0], '/Users/henryxu/Desktop/Research/prismio'))
from prismio.io_frame import IOFrame
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %%
hlrs64 = "/Users/henryxu/Desktop/Research/profiles/lassen/haccio/recorder-logs/hacc_io.regular.strong-scaling.64.524288.recorder-log"
hlrs128 = "/Users/henryxu/Desktop/Research/profiles/lassen/haccio/recorder-logs/hacc_io.regular.strong-scaling.128.262144.recorder-log"
hlrs256 = "/Users/henryxu/Desktop/Research/profiles/lassen/haccio/recorder-logs/hacc_io.regular.strong-scaling.256.131072.recorder-log"
hlrs512 = "/Users/henryxu/Desktop/Research/profiles/lassen/haccio/recorder-logs/hacc_io.regular.strong-scaling.512.65536.recorder-log"
hlrs1024 = "/Users/henryxu/Desktop/Research/profiles/lassen/haccio/recorder-logs/hacc_io.regular.strong-scaling.1024.32768.recorder-log"



hlbs64 = "/Users/henryxu/Desktop/Research/profiles/lassen/haccio/recorder-logs/hacc_io.bb.strong-scaling.64.524288.recorder-log"
hlbs128 = "/Users/henryxu/Desktop/Research/profiles/lassen/haccio/recorder-logs/hacc_io.bb.strong-scaling.128.262144.recorder-log"
hlbs256 = "/Users/henryxu/Desktop/Research/profiles/lassen/haccio/recorder-logs/hacc_io.bb.strong-scaling.256.131072.recorder-log"
hlbs512 = "/Users/henryxu/Desktop/Research/profiles/lassen/haccio/recorder-logs/hacc_io.bb.strong-scaling.512.65536.recorder-log"
hlbs1024 = "/Users/henryxu/Desktop/Research/profiles/lassen/haccio/recorder-logs/hacc_io.bb.strong-scaling.1024.32768.recorder-log"



hlrw64 = "/Users/henryxu/Desktop/Research/profiles/lassen/haccio/recorder-logs/hacc_io.regular.weak-scaling.64.131072.recorder-log"
hlrw128 = "/Users/henryxu/Desktop/Research/profiles/lassen/haccio/recorder-logs/hacc_io.regular.weak-scaling.128.131072.recorder-log"
hlrw256 = "/Users/henryxu/Desktop/Research/profiles/lassen/haccio/recorder-logs/hacc_io.regular.weak-scaling.256.131072.recorder-log"
hlrw512 = "/Users/henryxu/Desktop/Research/profiles/lassen/haccio/recorder-logs/hacc_io.regular.weak-scaling.512.131072.recorder-log"
hlrw1024 = "/Users/henryxu/Desktop/Research/profiles/lassen/haccio/recorder-logs/hacc_io.regular.weak-scaling.1024.131072.recorder-log"



hlbw64 = "/Users/henryxu/Desktop/Research/profiles/lassen/haccio/recorder-logs/hacc_io.bb.weak-scaling.64.131072.recorder-log"
hlbw128 = "/Users/henryxu/Desktop/Research/profiles/lassen/haccio/recorder-logs/hacc_io.bb.weak-scaling.128.131072.recorder-log"
hlbw256 = "/Users/henryxu/Desktop/Research/profiles/lassen/haccio/recorder-logs/hacc_io.bb.weak-scaling.256.131072.recorder-log"
hlbw512 = "/Users/henryxu/Desktop/Research/profiles/lassen/haccio/recorder-logs/hacc_io.bb.weak-scaling.512.131072.recorder-log"
hlbw1024 = "/Users/henryxu/Desktop/Research/profiles/lassen/haccio/recorder-logs/hacc_io.bb.weak-scaling.1024.131072.recorder-log"



hsrs64 = "/Users/henryxu/Desktop/Research/profiles/summit/haccio/recorder-logs/hacc_io.regular.strong-scaling.64.524288.recorder-log"
hsrs128 = "/Users/henryxu/Desktop/Research/profiles/summit/haccio/recorder-logs/hacc_io.regular.strong-scaling.128.262144.recorder-log"
hsrs256 = "/Users/henryxu/Desktop/Research/profiles/summit/haccio/recorder-logs/hacc_io.regular.strong-scaling.256.131072.recorder-log"
hsrs512 = "/Users/henryxu/Desktop/Research/profiles/summit/haccio/recorder-logs/hacc_io.regular.strong-scaling.512.65536.recorder-log"
hsrs1024 = "/Users/henryxu/Desktop/Research/profiles/summit/haccio/recorder-logs/hacc_io.regular.strong-scaling.1024.32768.recorder-log"



hsbs64 = "/Users/henryxu/Desktop/Research/profiles/summit/haccio/recorder-logs/hacc_io.bb.strong-scaling.64.524288.recorder-log"
hsbs128 = "/Users/henryxu/Desktop/Research/profiles/summit/haccio/recorder-logs/hacc_io.bb.strong-scaling.128.262144.recorder-log"
hsbs256 = "/Users/henryxu/Desktop/Research/profiles/summit/haccio/recorder-logs/hacc_io.bb.strong-scaling.256.131072.recorder-log"
hsbs512 = "/Users/henryxu/Desktop/Research/profiles/summit/haccio/recorder-logs/hacc_io.bb.strong-scaling.512.65536.recorder-log"
hsbs1024 = "/Users/henryxu/Desktop/Research/profiles/summit/haccio/recorder-logs/hacc_io.bb.strong-scaling.1024.32768.recorder-log"



hsrw64 = "/Users/henryxu/Desktop/Research/profiles/summit/haccio/recorder-logs/hacc_io.regular.weak-scaling.64.131072.recorder-log"
hsrw128 = "/Users/henryxu/Desktop/Research/profiles/summit/haccio/recorder-logs/hacc_io.regular.weak-scaling.128.131072.recorder-log"
hsrw256 = "/Users/henryxu/Desktop/Research/profiles/summit/haccio/recorder-logs/hacc_io.regular.weak-scaling.256.131072.recorder-log"
hsrw512 = "/Users/henryxu/Desktop/Research/profiles/summit/haccio/recorder-logs/hacc_io.regular.weak-scaling.512.131072.recorder-log"
hsrw1024 = "/Users/henryxu/Desktop/Research/profiles/summit/haccio/recorder-logs/hacc_io.regular.weak-scaling.1024.131072.recorder-log"



hsbw64 = "/Users/henryxu/Desktop/Research/profiles/summit/haccio/recorder-logs/hacc_io.bb.weak-scaling.64.131072.recorder-log"
hsbw128 = "/Users/henryxu/Desktop/Research/profiles/summit/haccio/recorder-logs/hacc_io.bb.weak-scaling.128.131072.recorder-log"
hsbw256 = "/Users/henryxu/Desktop/Research/profiles/summit/haccio/recorder-logs/hacc_io.bb.weak-scaling.256.131072.recorder-log"
hsbw512 = "/Users/henryxu/Desktop/Research/profiles/summit/haccio/recorder-logs/hacc_io.bb.weak-scaling.512.131072.recorder-log"
hsbw1024 = "/Users/henryxu/Desktop/Research/profiles/summit/haccio/recorder-logs/hacc_io.bb.weak-scaling.1024.131072.recorder-log"



hcrs64 = "/Users/henryxu/Desktop/Research/profiles/cori/haccio/recorder-logs/hacc_io.regular.strong-scaling.64.524288.recorder-log"
hcrs128 = "/Users/henryxu/Desktop/Research/profiles/cori/haccio/recorder-logs/hacc_io.regular.strong-scaling.128.262144.recorder-log"
hcrs256 = "/Users/henryxu/Desktop/Research/profiles/cori/haccio/recorder-logs/hacc_io.regular.strong-scaling.256.131072.recorder-log"
hcrs512 = "/Users/henryxu/Desktop/Research/profiles/cori/haccio/recorder-logs/hacc_io.regular.strong-scaling.512.65536.recorder-log"
hcrs1024 = "/Users/henryxu/Desktop/Research/profiles/cori/haccio/recorder-logs/hacc_io.regular.strong-scaling.1024.32768.recorder-log"



hcbs64_s1 = "/Users/henryxu/Desktop/Research/profiles/cori/haccio/recorder-logs/hacc_io.bb.strong-scaling.64.524288.recorder-log"
hcbs128_s1 = "/Users/henryxu/Desktop/Research/profiles/cori/haccio/recorder-logs/hacc_io.bb.strong-scaling.128.262144.recorder-log"
hcbs256_s1 = "/Users/henryxu/Desktop/Research/profiles/cori/haccio/recorder-logs/hacc_io.bb.strong-scaling.256.131072.recorder-log"
hcbs512_s1 = "/Users/henryxu/Desktop/Research/profiles/cori/haccio/recorder-logs/hacc_io.bb.strong-scaling.512.65536.recorder-log"
hcbs1024_s1 = "/Users/henryxu/Desktop/Research/profiles/cori/haccio/recorder-logs/hacc_io.bb.strong-scaling.1024.32768.recorder-log"



hcrw64 = "/Users/henryxu/Desktop/Research/profiles/cori/haccio/recorder-logs/hacc_io.regular.weak-scaling.64.131072.recorder-log"
hcrw128 = "/Users/henryxu/Desktop/Research/profiles/cori/haccio/recorder-logs/hacc_io.regular.weak-scaling.128.131072.recorder-log"
hcrw256 = "/Users/henryxu/Desktop/Research/profiles/cori/haccio/recorder-logs/hacc_io.regular.weak-scaling.256.131072.recorder-log"
hcrw512 = "/Users/henryxu/Desktop/Research/profiles/cori/haccio/recorder-logs/hacc_io.regular.weak-scaling.512.131072.recorder-log"
hcrw1024 = "/Users/henryxu/Desktop/Research/profiles/cori/haccio/recorder-logs/hacc_io.regular.weak-scaling.1024.131072.recorder-log"



hcbw64_s1 = "/Users/henryxu/Desktop/Research/profiles/cori/haccio/recorder-logs/hacc_io.bb.weak-scaling.64.131072.recorder-log"
hcbw128_s1 = "/Users/henryxu/Desktop/Research/profiles/cori/haccio/recorder-logs/hacc_io.bb.weak-scaling.128.131072.recorder-log"
hcbw256_s1 = "/Users/henryxu/Desktop/Research/profiles/cori/haccio/recorder-logs/hacc_io.bb.weak-scaling.256.131072.recorder-log"
hcbw512_s1 = "/Users/henryxu/Desktop/Research/profiles/cori/haccio/recorder-logs/hacc_io.bb.weak-scaling.512.131072.recorder-log"
hcbw1024_s1 = "/Users/henryxu/Desktop/Research/profiles/cori/haccio/recorder-logs/hacc_io.bb.weak-scaling.1024.131072.recorder-log"



hcbs64_s2 = "/Users/henryxu/Desktop/Research/profiles/cori/haccio/recorder-logs/hacc_io.bb.strip-2server.strong-scaling.64.524288.recorder-log"
hcbs128_s2 = "/Users/henryxu/Desktop/Research/profiles/cori/haccio/recorder-logs/hacc_io.bb.strip-2server.strong-scaling.128.262144.recorder-log"
hcbs256_s2 = "/Users/henryxu/Desktop/Research/profiles/cori/haccio/recorder-logs/hacc_io.bb.strip-2server.strong-scaling.256.131072.recorder-log"
hcbs512_s2 = "/Users/henryxu/Desktop/Research/profiles/cori/haccio/recorder-logs/hacc_io.bb.strip-2server.strong-scaling.512.65536.recorder-log"
hcbs1024_s2 = "/Users/henryxu/Desktop/Research/profiles/cori/haccio/recorder-logs/hacc_io.bb.strip-2server.strong-scaling.1024.32768.recorder-log"



hcbw64_s2 = "/Users/henryxu/Desktop/Research/profiles/cori/haccio/recorder-logs/hacc_io.bb.strip-2server.weak-scaling.64.131072.recorder-log"
hcbw128_s2 = "/Users/henryxu/Desktop/Research/profiles/cori/haccio/recorder-logs/hacc_io.bb.strip-2server.weak-scaling.128.131072.recorder-log"
hcbw256_s2 = "/Users/henryxu/Desktop/Research/profiles/cori/haccio/recorder-logs/hacc_io.bb.strip-2server.weak-scaling.256.131072.recorder-log"
hcbw512_s2 = "/Users/henryxu/Desktop/Research/profiles/cori/haccio/recorder-logs/hacc_io.bb.strip-2server.weak-scaling.512.131072.recorder-log"
hcbw1024_s2 = "/Users/henryxu/Desktop/Research/profiles/cori/haccio/recorder-logs/hacc_io.bb.strip-2server.weak-scaling.1024.131072.recorder-log"



hcbs64_s4 = "/Users/henryxu/Desktop/Research/profiles/cori/haccio/recorder-logs/hacc_io.bb.strip-4server.strong-scaling.64.524288.recorder-log"
hcbs128_s4 = "/Users/henryxu/Desktop/Research/profiles/cori/haccio/recorder-logs/hacc_io.bb.strip-4server.strong-scaling.128.262144.recorder-log"
hcbs256_s4 = "/Users/henryxu/Desktop/Research/profiles/cori/haccio/recorder-logs/hacc_io.bb.strip-4server.strong-scaling.256.131072.recorder-log"
hcbs512_s4 = "/Users/henryxu/Desktop/Research/profiles/cori/haccio/recorder-logs/hacc_io.bb.strip-4server.strong-scaling.512.65536.recorder-log"
hcbs1024_s4 = "/Users/henryxu/Desktop/Research/profiles/cori/haccio/recorder-logs/hacc_io.bb.strip-4server.strong-scaling.1024.32768.recorder-log"



hcbw64_s4 = "/Users/henryxu/Desktop/Research/profiles/cori/haccio/recorder-logs/hacc_io.bb.strip-4server.weak-scaling.64.131072.recorder-log"
hcbw128_s4 = "/Users/henryxu/Desktop/Research/profiles/cori/haccio/recorder-logs/hacc_io.bb.strip-4server.weak-scaling.128.131072.recorder-log"
hcbw256_s4 = "/Users/henryxu/Desktop/Research/profiles/cori/haccio/recorder-logs/hacc_io.bb.strip-4server.weak-scaling.256.131072.recorder-log"
hcbw512_s4 = "/Users/henryxu/Desktop/Research/profiles/cori/haccio/recorder-logs/hacc_io.bb.strip-4server.weak-scaling.512.131072.recorder-log"
hcbw1024_s4 = "/Users/henryxu/Desktop/Research/profiles/cori/haccio/recorder-logs/hacc_io.bb.strip-4server.weak-scaling.1024.131072.recorder-log"



hcbs64_s8 = "/Users/henryxu/Desktop/Research/profiles/cori/haccio/recorder-logs/hacc_io.bb.strip-8server.strong-scaling.64.524288.recorder-log"
hcbs128_s8 = "/Users/henryxu/Desktop/Research/profiles/cori/haccio/recorder-logs/hacc_io.bb.strip-8server.strong-scaling.128.262144.recorder-log"
hcbs256_s8 = "/Users/henryxu/Desktop/Research/profiles/cori/haccio/recorder-logs/hacc_io.bb.strip-8server.strong-scaling.256.131072.recorder-log"
hcbs512_s8 = "/Users/henryxu/Desktop/Research/profiles/cori/haccio/recorder-logs/hacc_io.bb.strip-8server.strong-scaling.512.65536.recorder-log"
hcbs1024_s8 = "/Users/henryxu/Desktop/Research/profiles/cori/haccio/recorder-logs/hacc_io.bb.strip-8server.strong-scaling.1024.32768.recorder-log"



hcbw64_s8 = "/Users/henryxu/Desktop/Research/profiles/cori/haccio/recorder-logs/hacc_io.bb.strip-8server.weak-scaling.64.131072.recorder-log"
hcbw128_s8 = "/Users/henryxu/Desktop/Research/profiles/cori/haccio/recorder-logs/hacc_io.bb.strip-8server.weak-scaling.128.131072.recorder-log"
hcbw256_s8 = "/Users/henryxu/Desktop/Research/profiles/cori/haccio/recorder-logs/hacc_io.bb.strip-8server.weak-scaling.256.131072.recorder-log"
hcbw512_s8 = "/Users/henryxu/Desktop/Research/profiles/cori/haccio/recorder-logs/hacc_io.bb.strip-8server.weak-scaling.512.131072.recorder-log"
hcbw1024_s8 = "/Users/henryxu/Desktop/Research/profiles/cori/haccio/recorder-logs/hacc_io.bb.strip-8server.weak-scaling.1024.131072.recorder-log"

# %%
hlrs = [hlrs64, hlrs128, hlrs256, hlrs512, hlrs1024]
hlbs = [hlbs64, hlbs128, hlbs256, hlbs512, hlbs1024]
hlrw = [hlrw64, hlrw128, hlrw256, hlrw512, hlrw1024]
hlbw = [hlbw64, hlbw128, hlbw256, hlbw512, hlbw1024]
hsrs = [hsrs64, hsrs128, hsrs256, hsrs512, hsrs1024]
hsbs = [hsbs64, hsbs128, hsbs256, hsbs512, hsbs1024]
hsrw = [hsrw64, hsrw128, hsrw256, hsrw512, hsrw1024]
hsbw = [hsbw64, hsbw128, hsbw256, hsbw512, hsbw1024]
hcrs = [hcrs64, hcrs128, hcrs256, hcrs512, hcrs1024]
hcrw = [hcrw64, hcrw128, hcrw256, hcrw512, hcrw1024]
hcb1s = [hcbs64_s1, hcbs128_s1, hcbs256_s1, hcbs512_s1, hcbs1024_s1]
hcb1w = [hcbw64_s1, hcbw128_s1, hcbw256_s1, hcbw512_s1, hcbw1024_s1]
hcb2s = [hcbs64_s2, hcbs128_s2, hcbs256_s2, hcbs512_s2, hcbs1024_s2]
hcb2w = [hcbw64_s2, hcbw128_s2, hcbw256_s2, hcbw512_s2, hcbw1024_s2]
hcb4s = [hcbs64_s4, hcbs128_s4, hcbs256_s4, hcbs512_s4, hcbs1024_s4]
hcb4w = [hcbw64_s4, hcbw128_s4, hcbw256_s4, hcbw512_s4, hcbw1024_s4]
hcb8s = [hcbs64_s8, hcbs128_s8, hcbs256_s8, hcbs512_s8, hcbs1024_s8]
hcb8w = [hcbw64_s8, hcbw128_s8, hcbw256_s8, hcbw512_s8, hcbw1024_s8]

dic = {
    'app': [],
    'io_subsystem': [],
    'scaling': [],
    'num_proc': [],
    'avg_transfer_size_per_read/write': [],
    'min_transfer_size_per_read/write': [],
    'max_transfer_size_per_read/write': [],
    'avg_io_bandwidth_per_read/write': [],
    'min_io_bandwidth_per_read/write': [],
    'max_io_bandwidth_per_read/write': [],
    'avg_io_bandwidth_per_rank': [],
    'min_io_bandwidth_per_rank': [],
    'max_io_bandwidth_per_rank': [],
    'avg_io_time_over_rank': [],
    'min_io_time_over_rank': [],
    'max_io_time_over_rank': [],
    'avg_transfer_time_over_rank': [],
    'min_transfer_time_over_rank': [],
    'max_transfer_time_over_rank': [],
    'avg_io_intensity_over_rank': [],
    'min_io_intensity_over_rank': [],
    'max_io_intensity_over_rank': [],
}

for io_subsystem, ioframe_io_subsystem in zip(
    ['lassen gpfs', 'lassen node-local bb', 'summit gpfs', 'summit node-local bb', 'cori lustre', 'cori 1 bb', 'cori 2 bb', 'cori 4 bb', 'cori 8 bb'], 
    [
        [hlrs, hlrw], [hlbs, hlbw], [hsrs, hsrw], [hsbs, hsbw], [hcrs, hcrw], 
        [hcb1s, hcb1w], [hcb2s, hcb2w], [hcb4s, hcb4w], [hcb8s, hcb8w]
    ]):
    for scaling, ioframe_sacling in zip(['strong-scaling', 'weak-scaling'], ioframe_io_subsystem):
        for num_proc, recorder_log in zip([64, 128, 256, 512, 1024], ioframe_sacling):
            ioframe = IOFrame.from_recorder(recorder_log)
            print("finish loading")
           
            dic['app'].append('haccio')
            dic['io_subsystem'].append(io_subsystem)
            dic['scaling'].append(scaling)
            dic['num_proc'].append(num_proc)
            
            avg_transfer_size = ioframe.dataframe['io_volume'].mean()
            min_transfer_size = ioframe.dataframe['io_volume'].min()
            max_transfer_size = ioframe.dataframe['io_volume'].max()
            dic['avg_transfer_size_per_read/write'].append(avg_transfer_size)
            dic['min_transfer_size_per_read/write'].append(min_transfer_size)
            dic['max_transfer_size_per_read/write'].append(max_transfer_size)
            
            dataframe = ioframe.dataframe[(ioframe.dataframe['io_volume'] > 1) & (ioframe.dataframe['time'] > 0)].copy()
            dataframe['io_bandwidth'] = dataframe['io_volume'] / dataframe['time']
            avg_io_bandwidth = dataframe['io_bandwidth'].mean()
            min_io_bandwidth = dataframe['io_bandwidth'].min()
            max_io_bandwidth = dataframe['io_bandwidth'].max()
            dic['avg_io_bandwidth_per_read/write'].append(avg_io_bandwidth)
            dic['min_io_bandwidth_per_read/write'].append(min_io_bandwidth)
            dic['max_io_bandwidth_per_read/write'].append(max_io_bandwidth)

            io_time = ioframe.io_time(io_type='write,read,meta', agg_function=np.sum, rank_major=True) # agg_column 
            avg_io_time = io_time["time_'write,read,meta'"].mean()
            min_io_time = io_time["time_'write,read,meta'"].min()
            max_io_time = io_time["time_'write,read,meta'"].max()
            dic['avg_io_time_over_rank'].append(avg_io_time)
            dic['min_io_time_over_rank'].append(min_io_time)
            dic['max_io_time_over_rank'].append(max_io_time)
            
            io_bandwidth_per_rank = ioframe.groupby_aggregate(['rank'], agg_dict={'io_volume': 'sum'})
            io_bandwidth_per_rank = pd.concat([io_bandwidth_per_rank, io_time["time_'write,read,meta'"]], axis=1)
            io_bandwidth_per_rank['io_bandwidth'] = io_bandwidth_per_rank['io_volume'] / io_bandwidth_per_rank["time_'write,read,meta'"]
            avg_io_bandwidth_per_rank = io_bandwidth_per_rank['io_bandwidth'].mean()
            min_io_bandwidth_per_rank = io_bandwidth_per_rank['io_bandwidth'].min()
            max_io_bandwidth_per_rank = io_bandwidth_per_rank['io_bandwidth'].max()
            dic['avg_io_bandwidth_per_rank'].append(avg_io_bandwidth_per_rank)
            dic['min_io_bandwidth_per_rank'].append(min_io_bandwidth_per_rank)
            dic['max_io_bandwidth_per_rank'].append(max_io_bandwidth_per_rank)

            transfer_time = ioframe.io_time(io_type='write,read', agg_function=np.sum, rank_major=True) # agg_column 
            avg_transfer_time = transfer_time["time_'write,read'"].mean()
            min_transfer_time = transfer_time["time_'write,read'"].min()
            max_transfer_time = transfer_time["time_'write,read'"].max()
            dic['avg_transfer_time_over_rank'].append(avg_transfer_time)
            dic['min_transfer_time_over_rank'].append(min_transfer_time)
            dic['max_transfer_time_over_rank'].append(max_transfer_time)
            
            avg_io_intensity = ioframe.time_distribution(ratio=True)['io_time'].mean()
            min_io_intensity = ioframe.time_distribution(ratio=True)['io_time'].min()
            max_io_intensity = ioframe.time_distribution(ratio=True)['io_time'].max()
            dic['avg_io_intensity_over_rank'].append(avg_io_intensity)
            dic['min_io_intensity_over_rank'].append(min_io_intensity)
            dic['max_io_intensity_over_rank'].append(max_io_intensity)
            

df = pd.DataFrame.from_dict(dic)
df.to_csv('/Users/henryxu/Desktop/io-project/data/analysis/haccio-io-info.csv', index=False)
# Out:
# [recorder-utils] Read trace file for rank: 0
# [recorder-utils] Read trace file for rank: 1
# [recorder-utils] Read trace file for rank: 2
# [recorder-utils] Read trace file for rank: 3
# [recorder-utils] Read trace file for rank: 4
# [recorder-utils] Read trace file for rank: 5
# [recorder-utils] Read trace file for rank: 6
# [recorder-utils] Read trace file for rank: 7
# [recorder-utils] Read trace file for rank: 8
# [recorder-utils] Read trace file for rank: 9
# [recorder-utils] Read trace file for rank: 10
# [recorder-utils] Read trace file for rank: 11
# [recorder-utils] Read trace file for rank: 12
# [recorder-utils] Read trace file for rank: 13
# [recorder-utils] Read trace file for rank: 14
# [recorder-utils] Read trace file for rank: 15
# [recorder-utils] Read trace file for rank: 16
# [recorder-utils] Read trace file for rank: 17
# [recorder-utils] Read trace file for rank: 18
# [recorder-utils] Read trace file for rank: 19
# [recorder-utils] Read trace file for rank: 20
# ...

# %%
print()
